# %%
import matplotlib.pyplot as plot

# %%
array = []
with open('SCORE.txt','r') as f:
    for line in f:
        a = line
        array.append(float(a))

box = [10 * i for i in range(len(array))]

plot.plot(box, array)

plot.show()
